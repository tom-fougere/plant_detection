# %%
import tensorflow as tf
import tensorflow_datasets as tfds
import numpy as np
import matplotlib.pyplot as plt

# %%
print('Tensorflow-dataset version:', tfds.__version__)
# Out:
# Tensorflow-dataset version: 4.2.0

# %%
# Load the "deep weeds" dataset
ds_train, ds_info = tfds.load('deep_weeds', split='train[:80%]', with_info=True)
ds_val = tfds.load('deep_weeds', split='train[80%:90%]')
ds_test = tfds.load('deep_weeds', split='train[90%:]')

# %%
# Show examples
tfds.show_examples(ds_train, ds_info);

# %%
# Get 1 image
image = tfds.as_numpy(ds_train['image'][0])
plt.imshow(image)

# %%
# Get 1 image
label_code = tfds.as_numpy(ds_train['label'][0])

# %%
class_names = np.array(ds_info.features['label'].names)
print(class_names)
# Out:
# ['Chinee apple' 'Lantana' 'Parkinsonia' 'Parthenium' 'Prickly acacia'
#  'Rubber vine' 'Siam weed' 'Snake weed' 'Negative']

# %%
print(class_names[label_code])
# Out:
# Lantana
